# %%
import wikipedia as wp 
from tqdm import tqdm

import json

# %%
def save_json(data, filename):
    with open(filename, 'w') as f:
        json.dump(data, f)

def load_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
class wiki:
    @staticmethod
    def get_page(title, debug=False):
        try:
            page = wp.page(title)
            if debug:
                print(f"Successfully downloaded article: {page.title}")
            return page
        except wp.PageError:
            if debug:
                print(f"Page '{title}' does not exist.")
            return None
    
    @staticmethod
    def get_content(title):
        page = wiki.get_page(title)
        return page.content if page is not None else ""

def save_texts(texts, file_name):
    with open(file_name, "w") as file:
        for text in texts:
            file.write(text + "\n---\n")

# %%
members_of_congress_wiki_pages_names = load_json("members_of_congress_wiki_pages.json")
members_of_congress_wiki_pages_names
# Out:
# {'Republicans': ['Barry Moore (Alabama politician)',
#   'Mike Rogers (Alabama politician)',
#   'Robert Aderholt',
#   'Dale Strong',
#   'Gary Palmer (politician)',
#   'Nick Begich III',
#   'David Schweikert',
#   'Eli Crane',
#   'Andy Biggs',
#   'Juan Ciscomani',
#   'Abraham Hamadeh',
#   'Paul Gosar',
#   'Rick Crawford (politician)',
#   'French Hill (politician)',
#   'Steve Womack',
#   'Bruce Westerman',
#   'Doug LaMalfa',
#   'Kevin Kiley (politician)',
#   'Tom McClintock',
#   'Vince Fong',
#   'David Valadao',
#   'Jay Obernolte',
#   'Young Kim',
#   'Ken Calvert',
#   'Darrell Issa',
#   'Jeff Hurd (politician)',
#   'Lauren Boebert',
#   'Jeff Crank',
#   'Gabe Evans',
#   'Neal Dunn',
#   'Kat Cammack',
#   'Aaron Bean',
#   'John Rutherford (Florida politician)',
#   'Cory Mills',
#   'Mike Haridopolos',
#   'Daniel Webster (Florida politician)',
#   'Gus Bilirakis',
#   'Anna Paulina Luna',
#   'Laurel Lee',
#   'Vern Buchanan',
#   'Greg Steube',
# ...

# %%
republicans_texts = []

for i in tqdm(range(len(members_of_congress_wiki_pages_names["Republicans"]))):
    title = members_of_congress_wiki_pages_names["Republicans"][i]
    republicans_texts.append(wiki.get_content(title))
# Out:
# 100%|██████████| 215/215 [03:59<00:00,  1.12s/it]

# %%
democrats_texts = []
for i in tqdm(range(len(members_of_congress_wiki_pages_names["Democrats"]))):
    title = members_of_congress_wiki_pages_names["Democrats"][i]
    democrats_texts.append(wiki.get_content(title))
# Out:
# 100%|██████████| 209/209 [03:51<00:00,  1.11s/it]

# %%
save_texts(democrats_texts, 'democrats.txt')
save_texts(republicans_texts, 'republicans.txt')

# %%
neg = set(opinion_lexicon.negative())
pos = set(opinion_lexicon.positive())

# %%
corp_rep = tm.corpus.Corpus(dict(zip(members_of_congress_wiki_pages_names["Republicans"], republicans_texts)), language = "en", load_features=[])
tm.corpus.filter_clean_tokens(corp_rep)
tm.corpus.to_lowercase(corp_rep)

df_rep = tm.corpus.tokens_table(corp_rep)
sent = pd.DataFrame([(tok in pos, tok in neg) for tok in df_rep["token"]], columns=["pos", "neg"])

df_rep = pd.concat([df_rep, sent], axis = 1)

df_rep
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 corp_rep = tm.corpus.Corpus(dict(zip(members_of_congress_wiki_pages_names["Republicans"], republicans_texts)), language = "en", load_features=[])
#       2 tm.corpus.filter_clean_tokens(corp_rep)
#       3 tm.corpus.to_lowercase(corp_rep)
#
# File ~/.local/share/virtualenvs/TEXT-Projekt-tlfdE9RI/lib/python3.10/site-packages/tmtoolkit/corpus/_corpus.py:214, in Corpus.__init__(self, docs, language, language_model, load_features, add_features, raw_preproc, spacy_token_attrs, spacy_instance, spacy_opts, punctuation, max_workers, workers_timeout)
#     212 # model meta information
#     213 if language_model not in spacy.util.get_installed_models():
# --> 214     raise RuntimeError(f'language model "{language_model}" cannot be loaded; are you sure it is installed? '
# ...

# %%
df_rep.groupby("doc")[["pos","neg"]].sum()

# %%
df_rep
